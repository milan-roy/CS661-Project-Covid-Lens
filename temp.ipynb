# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\milan\Desktop\Datasets\cases_deaths.csv")
df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 467745     Zimbabwe  2025-02-12        0.0       266404         0.0
# 467746     Zimbabwe  2025-02-13        0.0       266404         0.0
# 467747     Zimbabwe  2025-02-14        0.0       266404         0.0
# 467748     Zimbabwe  2025-02-15        0.0       266404         0.0
# 467749     Zimbabwe  2025-02-16        0.0       266404         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# ...
