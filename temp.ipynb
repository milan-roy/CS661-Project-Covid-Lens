# %%
import pandas as pd

# %%
cases_df = pd.read_csv('Datasets\Disease Spread\cases.csv')
cases_df = cases_df.groupby('country').tail(1).reset_index(drop=True)
cases_df
# Out:
#                                                country        date  new_cases  \
# 0                                          Afghanistan  2024-01-01      267.0
# 1                                               Africa  2024-01-01     2161.0
# 2                                              Albania  2024-01-01       57.0
# 3                                              Algeria  2024-01-01        0.0
# 4                                       American Samoa  2024-01-01        0.0
# ..                                                 ...         ...        ...
# 245                  World excl. China and South Korea  2024-01-01   170394.0
# 246  World excl. China South Korea Japan and Singapore  2024-01-01   149194.0
# 247                                              Yemen  2024-01-01        0.0
# 248                                             Zambia  2024-01-01        0.0
# 249                                           Zimbabwe  2024-01-01       46.0
#
# ...

# %%
cases_df[cases_df['continent'].isna()]
# Out:
#                                                country        date  new_cases  \
# 1                                               Africa  2024-01-01     2161.0
# 12                                                Asia  2024-01-01    29831.0
# 13                                    Asia excl. China  2024-01-01    29427.0
# 54                                             Curacao  2024-01-01        0.0
# 62                                          East Timor  2024-01-01        0.0
# 71                                              Europe  2024-01-01   117099.0
# 72                                 European Union (27)  2024-01-01    78264.0
# 73                                    Falkland Islands  2024-01-01        0.0
# 97                               High-income countries  2024-01-01   134560.0
# 116                                             Kosovo  2024-01-01        0.0
# 127                               Low-income countries  2024-01-01      381.0
# ...

# %%
total_cases_in_asia = cases_df[cases_df['continent'] == 'Oceania']['total_cases'].sum()
total_cases_in_asia
# Out:
# np.int64(14679887)
